# %% [markdown]
# ## TWITTER SCRAPING TASK
# ### KAUSTAV CHANDA  &nbsp;&nbsp;&nbsp;  https://github.com/Kaustav97
#
#
# ---

# %% [markdown]
# Install jsonlines, and import requred libraries.
# Keys required for the tweepy implementation below,  BeautifulSoup can operate without them, but since it scrapes a given page, cannot fetch more than ~20 lines.
#
# To work around this, I had 2 options:
#
# &nbsp;&nbsp;- Use a suporting library with BeautifulSoup to continue to gather data from pages with infinite scroll (like Twitter), such as cronjob etc.
#
# &nbsp;&nbsp;- Use the tweepy api after registering my app in the Twitter Developers portal.
#
# I have opted to go with the second solution, owing to its simplicity and ease of implementation.

# %%
pip install jsonlines
# Out:
# Collecting jsonlines
#   Downloading https://files.pythonhosted.org/packages/4f/9a/ab96291470e305504aa4b7a2e0ec132e930da89eb3ca7a82fbe03167c131/jsonlines-1.2.0-py2.py3-none-any.whl
# Requirement already satisfied: six in /usr/local/lib/python3.6/dist-packages (from jsonlines) (1.11.0)
# Installing collected packages: jsonlines
# Successfully installed jsonlines-1.2.0

# %%
import tweepy
from tweepy import OAuthHandler
import requests
from bs4 import BeautifulSoup
import re
import jsonlines

 
consumer_key = 'xxxxxxxxxxxxxxxxxxxxxxxxx'
consumer_secret = 'xxxxxxxxxxxxxxxxxxxxxxxxx'
access_token = 'xxxxxxxxxxxxxxxxxxxxxxxxx'
access_secret = 'xxxxxxxxxxxxxxxxxxxxxxxxx'
 
auth = OAuthHandler(consumer_key, consumer_secret)
auth.set_access_token(access_token, access_secret)
 
api = tweepy.API(auth)

# %% [markdown]
# **Approach 1**
#
#
# Use given Twitter handle as URL, requests library to send 'get' requests to the MIDAS Twitter handle.
#
# Upon closely inspecting the MIDAS Twitter homepage, all tweet content appeared in
# ```
# <div class="js-tweet-text-container">
# ```
#
# tags, so I ran a html selector to fetch all of them, to further parse for tweet content

# %%
url = 'https://twitter.com/midasIIITD'
data = requests.get(url)

# %%
html = BeautifulSoup(data.text, 'html.parser')
timeline = html.select('div.js-tweet-text-container')

# SAMPLE OF OBTAINED OUTPUT
print(timeline[:5])
# Out:
# [<div class="js-tweet-text-container">
# <p class="TweetTextSize TweetTextSize--normal js-tweet-text tweet-text" data-aria-label-part="0" lang="en">IEEE BigMM 2019 - Call for Workshop Proposals.
#
# Contact <a class="twitter-atreply pretty-link js-nav" data-mentioned-user-id="1021355762575073281" dir="ltr" href="/midasIIITD"><s>@</s><b>midasIIITD</b></a> <a class="twitter-atreply pretty-link js-nav" data-mentioned-user-id="932847441316999169" dir="ltr" href="/RatnRajiv"><s>@</s><b>RatnRajiv</b></a> <a class="twitter-atreply pretty-link js-nav" data-mentioned-user-id="73426884" dir="ltr" href="/debanjanbhucs"><s>@</s><b>debanjanbhucs</b></a> if you have any query.
#
# Deadlines:
# - Proposals due: April 1, 2019
# - Acceptance notification: April 10, 2019
#
# Further information:
# - Webpage: <a class="twitter-timeline-link" data-expanded-url="http://bigmm2019.org/index.php/calls-for-submission/workshops" dir="ltr" href="https://t.co/5XX5Wyxp5T" rel="nofollow noopener" target="_blank" title="http://bigmm2019.org/index.php/calls-for-submission/workshops"><span class="tco-ellipsis"></span><span class="invisible">http://</span><span class="js-display-url">bigmm2019.org/index.php/call</span><span class="invisible">s-for-submission/workshops</span><span class="tco-ellipsis"><span class="invisible"> </span>…</span></a>
# <a class="twitter-hashtag pretty-link js-nav" data-query-source="hashtag_click" dir="ltr" href="/hashtag/IEEE?src=hash"><s>#</s><b>IEEE</b></a> <a class="twitter-hashtag pretty-link js-nav" data-query-source="hashtag_click" dir="ltr" href="/hashtag/BigMM19?src=hash"><s>#</s><b>BigMM19</b></a></p>
# </div>, <div class="js-tweet-text-container">
# <p class="TweetTextSize TweetTextSize--normal js-tweet-text tweet-text" data-aria-label-part="0" lang="en">Hurry Up!
# 6 Days left for Abstract Submission in <a class="twitter-atreply pretty-link js-nav" data-mentioned-user-id="961976587246817280" dir="ltr" href="/ACMMM19"><s>@</s><b>ACMMM19</b></a>
# 45 Days left for Regular Paper Submission in <a class="twitter-atreply pretty-link js-nav" data-mentioned-user-id="1108061173130223616" dir="ltr" href="/IEEEBigMM19"><s>@</s><b>IEEEBigMM19</b></a> .
#
# Hectic time ahead or Multimedia Researchers :)</p>
# </div>, <div class="js-tweet-text-container">
# <p class="TweetTextSize TweetTextSize--normal js-tweet-text tweet-text" data-aria-label-part="0" lang="en">Congratulations <a class="twitter-atreply pretty-link js-nav" data-mentioned-user-id="1021355762575073281" dir="ltr" href="/midasIIITD"><s>@</s><b>midasIIITD</b></a> students Simra Shahid <a class="twitter-atreply pretty-link js-nav" data-mentioned-user-id="951083714682830848" dir="ltr" href="/Simcyy"><s>@</s><b>Simcyy</b></a> and Nilay Shrivastava <a class="twitter-atreply pretty-link js-nav" data-mentioned-user-id="2534161843" dir="ltr" href="/NilayShri"><s>@</s><b>NilayShri</b></a> on getting selected for a research internship at Adobe in this summer.
#
# <a class="twitter-hashtag pretty-link js-nav" data-query-source="hashtag_click" dir="ltr" href="/hashtag/MIDAS?src=hash"><s>#</s><b>MIDAS</b></a> <a class="twitter-hashtag pretty-link js-nav" data-query-source="hashtag_click" dir="ltr" href="/hashtag/Achievment?src=hash"><s>#</s><b>Achievment</b></a> <a class="twitter-hashtag pretty-link js-nav" data-query-source="hashtag_click" dir="ltr" href="/hashtag/Research?src=hash"><s>#</s><b>Research</b></a> <a class="twitter-hashtag pretty-link js-nav" data-query-source="hashtag_click" dir="ltr" href="/hashtag/Summer?src=hash"><s>#</s><b>Summer</b></a> <a class="twitter-hashtag pretty-link js-nav" data-query-source="hashtag_click" dir="ltr" href="/hashtag/Internship?src=hash"><s>#</s><b>Internship</b></a><a class="twitter-timeline-link u-hidden" data-pre-embedded="true" dir="ltr" href="https://t.co/WdF663EB5y">pic.twitter.com/WdF663EB5y</a></p>
# </div>, <div class="js-tweet-text-container">
# <p class="TweetTextSize TweetTextSize--normal js-tweet-text tweet-text" data-aria-label-part="0" lang="en">The last date for submitting a solution for the <a class="twitter-atreply pretty-link js-nav" data-mentioned-user-id="1021355762575073281" dir="ltr" href="/midasIIITD"><s>@</s><b>midasIIITD</b></a> internship task is 26th March midnight. We will not accept solutions submitted after the deadline.
# Thus, if you have not submitted your solution yet then kindly do so before the deadline.
# <a class="twitter-hashtag pretty-link js-nav" data-query-source="hashtag_click" dir="ltr" href="/hashtag/Summer?src=hash"><s>#</s><b>Summer</b></a> <a class="twitter-hashtag pretty-link js-nav" data-query-source="hashtag_click" dir="ltr" href="/hashtag/Research?src=hash"><s>#</s><b>Research</b></a> <a class="twitter-hashtag pretty-link js-nav" data-query-source="hashtag_click" dir="ltr" href="/hashtag/Internship?src=hash"><s>#</s><b>Internship</b></a></p>
# </div>, <div class="js-tweet-text-container">
# <p class="TweetTextSize TweetTextSize--normal js-tweet-text tweet-text" data-aria-label-part="0" lang="en"><a class="twitter-atreply pretty-link js-nav" data-mentioned-user-id="2227868629" dir="ltr" href="/IIITDelhi"><s>@</s><b>IIITDelhi</b></a> invites application from Foreign Nationals/PIOs/NRIs/OCIs for admission to its <a class="twitter-timeline-link" data-expanded-url="http://B.Tech" dir="ltr" href="https://t.co/u6kIuhIrGM" rel="nofollow noopener" target="_blank" title="http://B.Tech"><span class="tco-ellipsis"></span><span class="invisible">http://</span><span class="js-display-url">B.Tech</span><span class="invisible"></span><span class="tco-ellipsis"><span class="invisible"> </span></span></a> and <a class="twitter-timeline-link" data-expanded-url="http://M.Tech" dir="ltr" href="https://t.co/Q0ibR1xaDl" rel="nofollow noopener" target="_blank" title="http://M.Tech"><span class="tco-ellipsis"></span><span class="invisible">http://</span><span class="js-display-url">M.Tech</span><span class="invisible"></span><span class="tco-ellipsis"><span class="invisible"> </span></span></a> Programs through IIIT-Delhi admission process for AY 2019-20. Visit Website for more information : <a class="twitter-timeline-link" data-expanded-url="http://iiitd.ac.in/admission/foreign-students2019" dir="ltr" href="https://t.co/CGWqrughDw" rel="nofollow noopener" target="_blank" title="http://iiitd.ac.in/admission/foreign-students2019"><span class="tco-ellipsis"></span><span class="invisible">http://</span><span class="js-display-url">iiitd.ac.in/admission/fore</span><span class="invisible">ign-students2019</span><span class="tco-ellipsis"><span class="invisible"> </span>…</span></a><a class="twitter-timeline-link u-hidden" data-pre-embedded="true" dir="ltr" href="https://t.co/c2o3593dbR">pic.twitter.com/c2o3593dbR</a></p>
# </div>]

# %% [markdown]
# Observing the above obtained data, all tweet contents occur in NavigableString tags in the output obtained from the requests api.
#
# I have used a recursive appraoch to append all NavigableString tags to a list, and later just print that list, to get rid of the nested hierarchy in which contents and urls are presented. I have not continued with extracting the other information required in the question, because of the limited number of tweets obtained by this approach. Please see  **Approach 2** given below for final solution.

# %%
content= []
def resolveTag(tag):    
  if type(tag) is bs4.element.NavigableString:
    content.append(tag.strip())    
  else:
    for child in tag.children:            
      resolveTag(child)

# %%
content=[]
for tag in timeline:
  resolveTag(tag)  
print(''.join(content) )
# Out:
# IEEE BigMM 2019 - Call for Workshop Proposals.
#
# Contact@midasIIITD@RatnRajiv@debanjanbhucsif you have any query.
#
# Deadlines:
# - Proposals due: April 1, 2019
# - Acceptance notification: April 10, 2019
#
# Further information:
# - Webpage:http://bigmm2019.org/index.php/calls-for-submission/workshops…#IEEE#BigMM19Hurry Up!
# 6 Days left for Abstract Submission in@ACMMM1945 Days left for Regular Paper Submission in@IEEEBigMM19.
#
# Hectic time ahead or Multimedia Researchers :)Congratulations@midasIIITDstudents Simra Shahid@Simcyyand Nilay Shrivastava@NilayShrion getting selected for a research internship at Adobe in this summer.#MIDAS#Achievment#Research#Summer#Internshippic.twitter.com/WdF663EB5yThe last date for submitting a solution for the@midasIIITDinternship task is 26th March midnight. We will not accept solutions submitted after the deadline.
# Thus, if you have not submitted your solution yet then kindly do so before the deadline.#Summer#Research#Internship@IIITDelhiinvites application from Foreign Nationals/PIOs/NRIs/OCIs for admission to itshttp://B.Techandhttp://M.TechPrograms through IIIT-Delhi admission process for AY 2019-20. Visit Website for more information :http://iiitd.ac.in/admission/foreign-students2019…pic.twitter.com/c2o3593dbROne more week is left to submit the workshop proposal to@IEEEBigMM19.
# Looking forward to your submission. For any query, contact workshop co-chair Dr. Chiranjoy Chattopadhyay@cchattoor TPC co-chair@RatnRajivWe are honored to have Dr. Chang Wen Chen (Chinese University Hong Kong@CUHKofficial) and Dr. Roger Zimmermann (National University Singapore@NUSingapore) as our General co-chairs.Distinguished researchers Dr. Rajiv Ratn Shah@RatnRajiv(@IIITDelhi,@midasIIITD), Dr. Jianquan Liu (NEC Japan) and Dr. Vivek Singh (Rutgers University@RutgersU) will be our technical program co-chairs.BigMM 2019 : IEEE BigMM 2019 – Call for Workshop Proposalshttp://www.wikicfp.com/cfp/servlet/event.showcfp?eventid=86853&copyownerid=144925……
# When: Sep 11, 2019 - Sep 13, 2019
# Where: Singapore
# Submission Deadline: Apr 1, 2019
# Notification Due: Apr 10, 2019#IEEE#BigData#Singapore#MultimediaBigMM 2019 : IEEE BigMM 2019 – Call for Workshop Proposalshttp://www.wikicfp.com/cfp/servlet/event.showcfp?eventid=86853&copyownerid=144925…When: Sep 11, 2019 - Sep 13, 2019
# Where: Singapore
# Submission Deadline: Apr 1, 2019
# Notification Due: Apr 10, 2019#IEEE#BigMM#Workshop#Proposal#Singapore#MultimediaCongratulations@midasIIITDteam, Rohan, Pradyumn, Ramit,@debanjanbhucs,@MADAIguyand@RatnRajivfor getting their paper titled, "SNAP-BATNET: Cascading Author Profiling and Social Network Graphs for Suicide Ideation Detection on Social Media", accepted at@NAACLHLTSRW.We have emailed the task details to all shortlisted candidates for@midasIIITDinternship. Kindly check the same.
#
# If you are one of the shortlisted candidates and have not received the email then check your SPAM first before approaching.#MIDAS#Summer#Research#InternshipCongratulations! Arijit, Ramit,@debanjanbhucs@RatnRajivfor your@NAACLHLT@naaclSRW 2019 paper, "Speak Up, Fight Back! Detection of Social Media Disclosures of Sexual Harassment".
#
# Check more details athttps://www.linkedin.com/feed/update/urn:li:activity:6512397259563466752…#MeToo#Student#Research#Paper#NAACLWe will be releasing a very interesting task to shortlisted candidates for the internship at@midasIIITDtoday. You will be having 10 days to solve the same. You will get a detailed email on the task and submission instruction today. Looking forward to your out of box solution.Last day to register for#PortfolioCreationinDesignWorkshop Indraprastha Institute of Information Technology, Delhi on 15th March by Ankur Sardana
# Register at -https://goo.gl/PXyx94#HCDIIITD#workshoppic.twitter.com/EWQ7fuGNDDThe paper deadline is approaching. 1 April abstract is due. Authors will have until 8 April to upload the final PDF version of their paper submission. For complete submission information, seehttp://www.acmmm.org/2019/call-for-papers…@sigmm@TheOfficialACM@acmmmsys@ACMTVX@ACMICMR@eurommBookmark this amazing library of image augmentationsby#KaggleMasters@AlBuslaev@creaf@viglovikovand@cvtalks|https://github.com/albu/albumentations…#resources#machinelearningpic.twitter.com/QMOfNmU8dHAwesome members of our@midasIIITDteam who are working on Humonics projects. Great to have you on our team.#team#research#AI#ML#projectspic.twitter.com/lN7hItwPO9We are glad to inform that Adobe is launching Women’s day Tech-Challenge to hire female engineers from 2019 Batch under our#SheCodesinitiative.
# Please register here for participating in the challenge athttps://goo.gl/forms/IIVzLKgzn9TgKnxG2…Check full details athttps://www.linkedin.com/feed/update/urn:li:activity:6510841448202625025…We will email tasks to all shortlisted candidates for an internship at@midasIIITDby Friday, 15th March. If you are shortlisted and did not hear from us by that time then kindly drop an email to us.
#
# Looking forward to working with you.#research#Internship#AI@ACMMM19

# %%
len(timeline)
# Out:
# 20

# %% [markdown]
# **Approach 2**
#
# Here, i have gone forward with the tweepy method of scraping Twitter for the final solution, wherein I extract all the other required information in each tweet for likes, retweets, images, etc
#
# Final output can be viewed in **output.jsonl** file created by below script

# %%
with jsonlines.open('output.jsonl', mode='w') as writer:  
  for status in tweepy.Cursor(api.user_timeline, screen_name='@midasIIITD', tweet_mode="extended").items():    
    writer.write(status._json)

# %%
with jsonlines.open('output.jsonl') as reader:
    for obj in reader:      
      print(obj['full_text'])
      print("DATE : " , obj['created_at'] )
      print("FAVORITES: ",obj['favorite_count'])
      print("RETWEET COUNT: ",obj['retweet_count'])
      num_img=0
      try:
        for med in obj['entities']['media']:
          try:
            if(med['media_url']): num_img+=1
          except:
            continue    
        print("IMAGES: ",num_img)
      except:
        print("IMAGES: NONE")
      # Separator, indicating next tweet item in historical timeline        
      print("\n################################\n")
# Out:
# @IEEEBigMM19 @ACMMM19 and 6 days left for workshop proposal in @IEEEBigMM19.
#
# Contact @cchatto for any query.
# DATE :  Tue Mar 26 05:54:49 +0000 2019
# FAVORITES:  1
# RETWEET COUNT:  0
# IMAGES: NONE
#
# ################################
#
# RT @IEEEBigMM19: Hurry Up!
# 6 Days left for Abstract Submission in @ACMMM19
# 45 Days left for Regular Paper Submission in @IEEEBigMM19 .
#
# He…
# DATE :  Tue Mar 26 05:50:10 +0000 2019
# FAVORITES:  0
# RETWEET COUNT:  3
# IMAGES: NONE
#
# ################################
#
# Congratulations @midasIIITD students Simra Shahid @Simcyy and Nilay Shrivastava @NilayShri on getting selected for a research internship at Adobe in this summer.
#
# #MIDAS #Achievment #Research #Summer #Internship https://t.co/WdF663EB5y
# DATE :  Mon Mar 25 13:01:57 +0000 2019
# FAVORITES:  14
# RETWEET COUNT:  1
# IMAGES:  1
#
# ################################
#
# The last date for submitting a solution for the @midasIIITD internship task is 26th March midnight. We will not accept solutions submitted after the deadline.
# Thus, if you have not submitted your solution yet then kindly do so before the deadline.
# #Summer #Research #Internship
# DATE :  Sun Mar 24 18:44:01 +0000 2019
# FAVORITES:  8
# RETWEET COUNT:  3
# IMAGES: NONE
#
# ################################
#
# RT @IIITDelhi: @IIITDelhi invites application from Foreign Nationals/PIOs/NRIs/OCIs for admission to its https://t.co/u6kIuhIrGM and https:…
# DATE :  Sun Mar 24 18:26:02 +0000 2019
# FAVORITES:  0
# RETWEET COUNT:  4
# IMAGES: NONE
#
# ################################
#
# One more week is left to submit the workshop proposal to @IEEEBigMM19.
# Looking forward to your submission. For any query, contact workshop co-chair Dr. Chiranjoy Chattopadhyay @cchatto or TPC co-chair @RatnRajiv
# DATE :  Sun Mar 24 11:34:27 +0000 2019
# FAVORITES:  4
# RETWEET COUNT:  0
# IMAGES: NONE
#
# ################################
#
# RT @IEEEBigMM19: We are honored to have Dr. Chang Wen Chen (Chinese University Hong Kong @CUHKofficial ) and Dr. Roger Zimmermann (National…
# DATE :  Sun Mar 24 06:23:37 +0000 2019
# FAVORITES:  0
# RETWEET COUNT:  5
# IMAGES: NONE
#
# ################################
#
# RT @IEEEBigMM19: Distinguished researchers Dr. Rajiv Ratn Shah @RatnRajiv (@IIITDelhi , @midasIIITD ), Dr. Jianquan Liu (NEC Japan) and Dr.…
# DATE :  Sun Mar 24 06:23:14 +0000 2019
# FAVORITES:  0
# RETWEET COUNT:  3
# IMAGES: NONE
#
# ################################
#
# @IEEEBigMM19 is also available on Facebook now.
# LIKE its Facebook page https://t.co/B3Q0zmmzXb  to get the regular updates.
# Check more details at https://t.co/w9ZymoPisk
#
# #IEEE #BigMM19 #Big #Multimedia #Singapore
# DATE :  Wed Mar 20 08:19:24 +0000 2019
# FAVORITES:  1
# RETWEET COUNT:  1
# IMAGES: NONE
#
# ################################
#
# RT @IEEEBigMM19: BigMM 2019 : IEEE BigMM 2019 – Call for Workshop Proposals
#
# https://t.co/I4vqf8FE6K …
# When: Sep 11, 2019 - Sep 13, 201…
# DATE :  Wed Mar 20 02:40:07 +0000 2019
# FAVORITES:  0
# RETWEET COUNT:  5
# IMAGES: NONE
#
# ################################
#
# BigMM 2019 : IEEE BigMM 2019 – Call for Workshop Proposals
#
# https://t.co/oUq2G0UgKN
#
# When: Sep 11, 2019 - Sep 13, 2019
# Where: Singapore
# Submission Deadline: Apr 1, 2019
# Notification Due: Apr 10, 2019
#
# #IEEE #BigMM #Workshop #Proposal #Singapore #Multimedia
# DATE :  Mon Mar 18 02:27:47 +0000 2019
# FAVORITES:  6
# RETWEET COUNT:  3
# IMAGES: NONE
#
# ################################
#
# Congratulations @midasIIITD team, Rohan, Pradyumn, Ramit, @debanjanbhucs, @MADAIguy and @RatnRajiv for getting their paper titled, "SNAP-BATNET: Cascading Author Profiling and Social Network Graphs for Suicide Ideation Detection on Social Media", accepted at @NAACLHLT SRW.
# DATE :  Sun Mar 17 14:22:04 +0000 2019
# FAVORITES:  15
# RETWEET COUNT:  4
# IMAGES: NONE
#
# ################################
#
# We have emailed the task details to all shortlisted candidates for @midasIIITD internship. Kindly check the same.
#
# If you are one of the shortlisted candidates and have not received the email then check your SPAM first before approaching.
#
# #MIDAS #Summer #Research #Internship
# DATE :  Sat Mar 16 14:06:56 +0000 2019
# FAVORITES:  7
# RETWEET COUNT:  0
# IMAGES: NONE
#
# ################################
#
# IEEE BigMM 2019 - Call for Workshop Proposals.
#
# Contact @midasIIITD @RatnRajiv @debanjanbhucs if you have any query.
#
# Deadlines:
# - Proposals due: April 1, 2019
# - Acceptance notification: April 10, 2019
#
# Further information:
# - Webpage: https://t.co/5XX5Wyxp5T
#
# #IEEE #BigMM19
# DATE :  Sat Mar 16 09:20:29 +0000 2019
# FAVORITES:  1
# RETWEET COUNT:  1
# IMAGES: NONE
#
# ################################
#
# Congratulations! Arijit, Ramit, @debanjanbhucs @RatnRajiv for your @NAACLHLT  @naacl SRW 2019 paper, "Speak Up, Fight Back! Detection of Social Media Disclosures of Sexual Harassment".
#
# Check more details at https://t.co/i6eAHg7gcN
#
# #MeToo #Student #Research  #Paper #NAACL
# DATE :  Sat Mar 16 09:14:58 +0000 2019
# FAVORITES:  7
# RETWEET COUNT:  2
# IMAGES: NONE
#
# ################################
#
# We will be releasing a very interesting task to shortlisted candidates for the internship at @midasIIITD today. You will be having 10 days to solve the same. You will get a detailed email on the task and submission instruction today. Looking forward to your out of box solution.
# DATE :  Sat Mar 16 05:13:14 +0000 2019
# FAVORITES:  7
# RETWEET COUNT:  2
# IMAGES: NONE
#
# ################################
#
# RT @hcdiiitd: Last day to register for #PortfolioCreationinDesign Workshop Indraprastha Institute of Information Technology, Delhi on 15th…
# DATE :  Wed Mar 13 17:09:44 +0000 2019
# FAVORITES:  0
# RETWEET COUNT:  2
# IMAGES: NONE
#
# ################################
#
# @ACMMM19 @sigmm @TheOfficialACM @acmmmsys @ACMTVX @ACMICMR @euromm @Benoit_Huet @RatnRajiv @kelkalot
# We need to clearly mention abstract and final submission deadlines at https://t.co/U7DTNNyw87
#
# Currently, we have just mentioned 1st April as the regular paper submission deadline. Kindly update.
#
# #ACMMM19 #Nice #Multimedia https://t.co/ocOCrlFHLH
# DATE :  Wed Mar 13 04:11:24 +0000 2019
# FAVORITES:  1
# RETWEET COUNT:  0
# IMAGES:  1
#
# ################################
#
# RT @ACMMM19: The paper deadline is approaching. 1 April abstract is due. Authors will have until 8 April to upload the final PDF version of…
# DATE :  Wed Mar 13 04:06:04 +0000 2019
# FAVORITES:  0
# RETWEET COUNT:  13
# IMAGES: NONE
#
# ################################
#
# RT @kaggle: Bookmark this amazing library of image augmentations 😵 by #Kaggle Masters @AlBuslaev @creaf @viglovikov and @cvtalks | https://…
# DATE :  Tue Mar 12 17:43:44 +0000 2019
# FAVORITES:  0
# RETWEET COUNT:  67
# IMAGES: NONE
#
# ################################
#
# Awesome members of our @midasIIITD team who are working on Humonics projects. Great to have you on our team.
#
# #team #research #AI #ML #projects https://t.co/lN7hItwPO9
# DATE :  Tue Mar 12 14:37:55 +0000 2019
# FAVORITES:  16
# RETWEET COUNT:  4
# IMAGES:  1
#
# ################################
#
# @saanidhi @ACMMM19 Before Friday, 15th March.
# DATE :  Mon Mar 11 14:58:30 +0000 2019
# FAVORITES:  0
# RETWEET COUNT:  0
# IMAGES: NONE
#
# ################################
#
# We are glad to inform that Adobe is launching Women’s day Tech-Challenge to hire female engineers from 2019 Batch under our #SheCodes initiative.
# Please register here for participating in the challenge at https://t.co/DjkKCJHDBC
#
# Check full details at https://t.co/5ArLu3icva
# DATE :  Mon Mar 11 12:02:42 +0000 2019
# FAVORITES:  4
# RETWEET COUNT:  0
# IMAGES: NONE
#
# ################################
#
# We will email tasks to all shortlisted candidates for an internship at @midasIIITD by Friday, 15th March. If you are shortlisted and did not hear from us by that time then kindly drop an email to us.
#
# Looking forward to working with you.
#
# #research #Internship #AI @ACMMM19
# DATE :  Mon Mar 11 11:54:38 +0000 2019
# FAVORITES:  3
# RETWEET COUNT:  0
# IMAGES: NONE
#
# ################################
#
# @ACMMM19 @ACM_MM2018 @acmmm17 @sigmm @ACM Less than three weeks are left for @ACMMM19 submission.
# Looking forward to your contribution to #ACMMM and see you in Nice, France.
# @midasIIITD @iiit_hyderabad @iitdelhi @abhinavdhall @iitmadras @iiscbangalore @IITKanpur @iitbombay @iitkharagpur @IITJodhpur @iitropar @IIITDelhi
# DATE :  Mon Mar 11 06:22:12 +0000 2019
# FAVORITES:  1
# RETWEET COUNT:  1
# IMAGES: NONE
#
# ################################
#
# RT @kdnuggets: Face Recognition using One-Shot Learning – #DeepLearning
# using DL architecture that works great with one-shot learning calle…
# DATE :  Mon Mar 11 06:17:20 +0000 2019
# FAVORITES:  0
# RETWEET COUNT:  64
# IMAGES: NONE
#
# ################################
#
# @AvinashSwamina2 @IIITDelhi No. They will be given tasks along with students who will be selected in the second round.
# DATE :  Fri Mar 08 13:22:07 +0000 2019
# FAVORITES:  1
# RETWEET COUNT:  0
# IMAGES: NONE
#
# ################################
#
# We are in the process of finalizing the shortlisted candidates for internship at @midasIIITD which we have received in the second round.
# We will assign tasks to all shortlisted candidates around early next week. We are also delaying the task since DTU has mid-sem until 15 March.
# DATE :  Fri Mar 08 13:15:34 +0000 2019
# FAVORITES:  8
# RETWEET COUNT:  4
# IMAGES: NONE
#
# ################################
#
# @ylecun @NilayShri @the_dhumketu @debanjanbhucs will it be useful?
# DATE :  Wed Mar 06 13:44:11 +0000 2019
# FAVORITES:  3
# RETWEET COUNT:  0
# IMAGES: NONE
#
# ################################
#
# RT @kdnuggets: Python Data Science for Beginners https://t.co/yRExdmdZGh https://t.co/vRqTRuayO3
# DATE :  Wed Mar 06 11:12:30 +0000 2019
# FAVORITES:  0
# RETWEET COUNT:  22
# IMAGES:  1
#
# ################################
#
# RT @stanfordnlp: Useful feature of our Python stanfordnlp: get lemmas &amp; morphology in many languages. Le ski de fond touché→lemma toucher f…
# DATE :  Sun Mar 03 19:36:04 +0000 2019
# FAVORITES:  0
# RETWEET COUNT:  35
# IMAGES: NONE
#
# ################################
#
# @NilayShri @NilayShri, Certain thing! The next team outing will be for lipreading team.
# Probably, just after @ACMMM19 submission.
# DATE :  Sun Mar 03 17:09:48 +0000 2019
# FAVORITES:  1
# RETWEET COUNT:  0
# IMAGES: NONE
#
# ################################
#
# At @midasIIITD, we not only work hard but also have fun.
# Today, we had a team (for Humonics sponsored projects) outing at Pirates of Grill. It was a wonderful day with lots of fun.
#
# #fun #lunch #MIDAS https://t.co/MEVA1NfHRd
# DATE :  Sun Mar 03 15:37:28 +0000 2019
# FAVORITES:  9
# RETWEET COUNT:  1
# IMAGES:  1
#
# ################################
#
# Considering several requests to extend the deadline for internship application, @midasIIITD at @IIITDelhi has decided that we will open the internship form https://t.co/t54AZ9eo26 again on March 7 and process all application received by March 8, 10 am.
#
# #research #Internship #AI
# DATE :  Sun Mar 03 14:55:31 +0000 2019
# FAVORITES:  6
# RETWEET COUNT:  2
# IMAGES: NONE
#
# ################################
#
# RT @jeremyphoward: 39 studies about human perception in 30 minutes by @kennelliott
#
# Awesome article. If you do any visualization or comput…
# DATE :  Sun Mar 03 14:26:40 +0000 2019
# FAVORITES:  0
# RETWEET COUNT:  315
# IMAGES: NONE
#
# ################################
#
# Correction:   @midasIIITD at @IIITDelhi
# DATE :  Sat Mar 02 17:43:05 +0000 2019
# FAVORITES:  1
# RETWEET COUNT:  0
# IMAGES: NONE
#
# ################################
#
# Thanks much to all aspirants who have applied for the summer internship 2019 at @midasIIITD at @midasIIITD. We have received over 200 applications. Thus, many good applications are not selected for next round. We have sent emails to all candidates, kindly check that for results.
# DATE :  Sat Mar 02 09:59:03 +0000 2019
# FAVORITES:  7
# RETWEET COUNT:  1
# IMAGES: NONE
#
# ################################
#
# RT @kdnuggets: Keras Hyperparameter Tuning in Google Colab Using Hyperas https://t.co/hmaI4ukJRX https://t.co/s3nTqqgnAb
# DATE :  Thu Feb 28 14:21:21 +0000 2019
# FAVORITES:  0
# RETWEET COUNT:  4
# IMAGES:  1
#
# ################################
#
# RT @RatnRajiv: Great meeting with @midasIIITD alumnus, Sanket Jain today.
# He was among first MTech students who worked with me at @IIITDelh…
# DATE :  Tue Feb 26 18:30:52 +0000 2019
# FAVORITES:  0
# RETWEET COUNT:  1
# IMAGES: NONE
#
# ################################
#
# Correction: They have published the following paper only:
#
# PROMPT: Personalized User Tag Recommendation for Social Media Photos Leveraging Personal and Social Contexts.
# DATE :  Tue Feb 26 03:40:22 +0000 2019
# FAVORITES:  0
# RETWEET COUNT:  0
# IMAGES: NONE
#
# ################################
#
# We will process all applications received by March 1, 2019 and notify all shortlisted candidates by March 3.
#
# If you have not applied yet for @midasIIITD internship then you may do so by filling the form https://t.co/t54AZ9eo26
#
# #MIDAS #IIITD #Internship #NLP #ML #AI #DL #CV
# DATE :  Mon Feb 25 16:10:46 +0000 2019
# FAVORITES:  2
# RETWEET COUNT:  1
# IMAGES: NONE
#
# ################################
#
# RT @ecsquendor: Jit Ghosh discusses the "GloVe" 2014 Stanford paper on word embeddings. This one was a great session! #paperreviewcalls #nl…
# DATE :  Sun Feb 24 03:39:40 +0000 2019
# FAVORITES:  0
# RETWEET COUNT:  8
# IMAGES: NONE
#
# ################################
#
# RT @goodfellow_ian: This CVPR workshop is looking for applications of computer vision in developing countries. You don't need to submit a f…
# DATE :  Sat Feb 23 15:41:27 +0000 2019
# FAVORITES:  0
# RETWEET COUNT:  90
# IMAGES: NONE
#
# ################################
#
# RT @IIITDelhi: PhD Admission 2019 are open now
#
# Online applications starts from 20th February 2019 and the last date to apply is 14th March…
# DATE :  Fri Feb 22 11:54:49 +0000 2019
# FAVORITES:  0
# RETWEET COUNT:  8
# IMAGES: NONE
#
# ################################
#
# RT @kdnuggets: #AI for Social Good study - how to inform policy, achieve interpretability, reduce bias and more -
# include review of global…
# DATE :  Thu Feb 21 16:27:54 +0000 2019
# FAVORITES:  0
# RETWEET COUNT:  13
# IMAGES: NONE
#
# ################################
#
# @IIITDelhi has initiated PhD Admission 2019 process (Regular Round).
#
# Online applications start from 20th February 2019 and the last date to apply is 14th March 2019.
#
# For more details please visit the following link: https://t.co/qWa9I7CFqX.
#
# #IIITD #PhD #Admission
# DATE :  Thu Feb 21 06:39:27 +0000 2019
# FAVORITES:  2
# RETWEET COUNT:  1
# IMAGES: NONE
#
# ################################
#
# RT @radamihalcea: We tend to focus mainly on creating learning algorithms, and yet there is so much that can be gained from unlearning. In…
# DATE :  Thu Feb 21 04:48:24 +0000 2019
# FAVORITES:  0
# RETWEET COUNT:  13
# IMAGES: NONE
#
# ################################
#
# @RealAAAI @RatnRajiv Thanks, @RealAAAI for recognizing our efforts.
#
# Congratulations, @midasIIITD students for winning Best Student Poster award at 33rd AAAI Conference on Artificial Intelligence.
#
# Many thanks to authors, Raghav, @the_dhumketu Kshitij, @RatnRajiv @ponguru and Roger.
#
# #AAAI19 #AI https://t.co/oKy1OYCOAR
# DATE :  Wed Feb 20 07:09:19 +0000 2019
# FAVORITES:  6
# RETWEET COUNT:  2
# IMAGES:  1
#
# ################################
#
# Deepak Gupta, has joined @Google today.
# Earlier this week, Anupam Samanta, has also joined Google.
# Both will be working at Google office in Mount View, California, USA. Having immense pride to see their success.
#
# They have published two papers with @midasIIITD head @RatnRajiv https://t.co/QEiIs5nTSn
# DATE :  Wed Feb 20 05:38:29 +0000 2019
# FAVORITES:  4
# RETWEET COUNT:  2
# IMAGES:  1
#
# ################################
#
# RT @ACMMM19: We are pleased to announce the multimedia Grand Challenges that will be offered at ACM Multimedia in 2019. Check out the list;…
# DATE :  Tue Feb 19 17:16:24 +0000 2019
# FAVORITES:  0
# RETWEET COUNT:  15
# IMAGES: NONE
#
# ################################
#
# In addition to projects related to NLP and Multimedia systems, we have open positions for 3D animation interns too.
# Candidate should have knowledge of Maya character animation, modeling, and good drawing skills.
#
# To apply, fill https://t.co/t54AZ9eo26
# and mention "3D Animation"
# DATE :  Tue Feb 19 04:29:33 +0000 2019
# FAVORITES:  3
# RETWEET COUNT:  2
# IMAGES: NONE
#
# ################################
#
# RT @technology: What could the manufacturing industry teach healthcare?
# DATE :  Tue Feb 19 04:19:05 +0000 2019
# FAVORITES:  0
# RETWEET COUNT:  292
# IMAGES: NONE
#
# ################################
#
# RT @MSFTResearch: Dr. Layla El Asri wants you to be able to talk to your machine just like you’d talk to another person. That’s the easy pa…
# DATE :  Tue Feb 19 04:18:53 +0000 2019
# FAVORITES:  0
# RETWEET COUNT:  21
# IMAGES: NONE
#
# ################################
#
# To apply for @midasIIITD internship at @IIITDelhi, fill the following form: https://t.co/t54AZ9eo26
#
# Check more details at https://t.co/GvP3wsWtzX
#
# Pls share @debanjanbhucs @RatnRajiv @the_dhumketu @Hitkul_ @NilayShri
#
# #Research #Internship #Multimedia #NLP #ML #DeepLearning
# DATE :  Mon Feb 18 17:29:44 +0000 2019
# FAVORITES:  11
# RETWEET COUNT:  9
# IMAGES: NONE
#
# ################################
#
# RT @CornellDyson: Digital ag is Cornell’s newest radical collaboration initiative→https://t.co/hVXSnoSbnS
# #DigitalAg #Cornell @CornellNews…
# DATE :  Mon Feb 18 05:37:59 +0000 2019
# FAVORITES:  0
# RETWEET COUNT:  6
# IMAGES: NONE
#
# ################################
#
# RT @odsc: Introduction to StanfordNLP: a state-of-the-art NLP library for 53 languages @StanfordNLP #DataScience #NLP #NaturalLanguageProce…
# DATE :  Sun Feb 17 17:22:06 +0000 2019
# FAVORITES:  0
# RETWEET COUNT:  50
# IMAGES: NONE
#
# ################################
#
# Looking forward to your participation in Multimedia Grand Challenges of @ACMMM19
#
# Several interesting challenges are available at https://t.co/mGYxuvrve5
#
# @midasIIITD lab is looking forward to helping students from Indian institutes who plan to participate.
#
# #ACMMM #Multimedia
# DATE :  Sun Feb 17 09:02:28 +0000 2019
# FAVORITES:  3
# RETWEET COUNT:  1
# IMAGES: NONE
#
# ################################
#
# Consider attending National Workshop on Intelligent Multimodal Interfaces (NWIMI) at Indian Institute of Technology Jodhpur @IITJodhpur from March 9-10, 2019.
#
# Check more details at https://t.co/lLLzl0dUaI
# DATE :  Sun Feb 17 08:49:36 +0000 2019
# FAVORITES:  1
# RETWEET COUNT:  0
# IMAGES: NONE
#
# ################################
#
# Submissions are invited for a special issue of Cognitive Computation (Impact Factor: 3.479) on Affect Recognition in Multimodal Language.
#
# CFP - https://t.co/vP2Naq1C85
#
# Submission deadline - 05/05/2019
#
# Contact @soujanyaporia for further details.
# DATE :  Sun Feb 17 06:39:30 +0000 2019
# FAVORITES:  1
# RETWEET COUNT:  1
# IMAGES: NONE
#
# ################################
#
# RT @debanjanbhucs: https://t.co/qNFzJ7ZHki
# DATE :  Sat Feb 16 16:57:51 +0000 2019
# FAVORITES:  0
# RETWEET COUNT:  1
# IMAGES: NONE
#
# ################################
#
# RT @MSFTResearch: Congratulations to Manik Varma, @iitdelhi's Himanshu Jain, Venkatesh Balasubramanian and Bhanu Chunduri for winning the B…
# DATE :  Fri Feb 15 08:22:23 +0000 2019
# FAVORITES:  0
# RETWEET COUNT:  13
# IMAGES: NONE
#
# ################################
#
# Congratulations! Anupam Samanta on joining @Google as a software engineer.
#
# Anupam worked with @midasIIITD head, Dr @RatnRajiv and published two research papers. Great to hear that Anupam got ML and Data Science team in Google due to his research experience and publications. https://t.co/IcuBbjEkjc
# DATE :  Thu Feb 14 15:56:14 +0000 2019
# FAVORITES:  14
# RETWEET COUNT:  4
# IMAGES:  1
#
# ################################
#
# RT @kdnuggets: Using BERT for state-of-the-art pre-training for natural language processing https://t.co/wAyERwPw3r https://t.co/ghPTpClh3p
# DATE :  Wed Feb 13 18:56:13 +0000 2019
# FAVORITES:  0
# RETWEET COUNT:  5
# IMAGES:  1
#
# ################################
#
# RT @ACMMM19: Attention authors of ACM MultiMedia 2018 and 2017 main conference papers. Submit a reproducibility paper to ACMMM 2019 https:/…
# DATE :  Wed Feb 13 15:54:52 +0000 2019
# FAVORITES:  0
# RETWEET COUNT:  11
# IMAGES: NONE
#
# ################################
#
# RT @kdnuggets: 9 Must-have skills you need to become a Data Scientist, updated https://t.co/OeeComtoWu https://t.co/DGq5qrQefc
# DATE :  Wed Feb 13 05:56:05 +0000 2019
# FAVORITES:  0
# RETWEET COUNT:  11
# IMAGES:  1
#
# ################################
#
# @ACMMM19 @ACM Just one week is left for workshop proposal. Kindly consider submitting it.
# @midasIIITD @abhinavdhall @IIITDelhi @iiit_hyderabad @iitdelhi @IITKanpur @iiscbangalore @IITKgp @debanjanbhucs @the_dhumketu @RatnRajiv @fire_forum @iitmadras @soujanyaporia @NTUsg @iitbombay #ACMMM19
# DATE :  Thu Feb 07 19:21:52 +0000 2019
# FAVORITES:  1
# RETWEET COUNT:  1
# IMAGES: NONE
#
# ################################
#
# @NilayShri @the_dhumketu Thanks, @NilayShri for sharing.
# Indeed a very good work.
# DATE :  Thu Feb 07 15:49:59 +0000 2019
# FAVORITES:  0
# RETWEET COUNT:  0
# IMAGES: NONE
#
# ################################
#
# RT @NilayShri: @midasIIITD @the_dhumketu this seems to be the 'trend' https://t.co/m6YfyTtwfX
# DATE :  Thu Feb 07 15:49:08 +0000 2019
# FAVORITES:  0
# RETWEET COUNT:  1
# IMAGES: NONE
#
# ################################
#
# RT @kdnuggets: Machine Learning in Python by @PyImageSearch
# "Struggling to get started with machine learning using Python? In this step-by-…
# DATE :  Thu Feb 07 06:23:10 +0000 2019
# FAVORITES:  0
# RETWEET COUNT:  53
# IMAGES: NONE
#
# ################################
#
# RT @Cambridge_Uni: .@DeepMindAI and @Cambridge_Trust  are offering scholarships to under-represented students to study computer science. Op…
# DATE :  Wed Feb 06 11:26:25 +0000 2019
# FAVORITES:  0
# RETWEET COUNT:  35
# IMAGES: NONE
#
# ################################
#
# RT @GoogleAI: Google AI  and @DeepMindAI researchers have open-sourced the Hanabi Learning Environment, a testbed for collaborative multi-a…
# DATE :  Tue Feb 05 18:32:54 +0000 2019
# FAVORITES:  0
# RETWEET COUNT:  212
# IMAGES: NONE
#
# ################################
#
# Edit: In the updated leaderboard we are now ranked 10th in the suggestion mining task! Thanks for updates @isarth23
# DATE :  Tue Feb 05 17:45:09 +0000 2019
# FAVORITES:  0
# RETWEET COUNT:  0
# IMAGES: NONE
#
# ################################
#
# Congratulations! @isarth23.
# It is our pleasure to work with you.
# You are a gem of @midasIIITD. https://t.co/mOJQyhd26K
# DATE :  Tue Feb 05 17:44:27 +0000 2019
# FAVORITES:  4
# RETWEET COUNT:  0
# IMAGES: NONE
#
# ################################
#
# In addition to OffensEval task, @midasIIITD has also performed well in the suggestion mining task (https://t.co/UiloRZiYSr) of SemEval 19.
#
# We secured 11th rank in this task.
#
# Congrats! @debanjanbhucs Raymond, Karan Uppal, @isarth23 @the_dhumketu @RatnRajiv for your hard work.
# DATE :  Tue Feb 05 12:09:44 +0000 2019
# FAVORITES:  5
# RETWEET COUNT:  1
# IMAGES: NONE
#
# ################################
#
# Thanks, Karan Uppal and @RatnRajiv for all your support.
# DATE :  Tue Feb 05 11:55:41 +0000 2019
# FAVORITES:  1
# RETWEET COUNT:  1
# IMAGES: NONE
#
# ################################
#
# @midasIIITD performance in OffensEval 2019 (SemEval 2019 - Task 6).
#
# In subtask-A, we came 5th out of 103 teams
# In subtask-B, we came 8th out of 75 teams
# We are very close to best results.
#
# Congratulations! @debanjanbhucs, Raymond, @isarth23, @the_dhumketu, @LaibaMehnaz, @Simcyy https://t.co/NveQlv8wO8
# DATE :  Tue Feb 05 11:06:31 +0000 2019
# FAVORITES:  4
# RETWEET COUNT:  3
# IMAGES:  1
#
# ################################
#
# RT @ProfAnirban: One of the biggest obstacles to the adoption of #NLP and cognitive #AI is the lack of pretrained models in languages other…
# DATE :  Mon Feb 04 12:16:16 +0000 2019
# FAVORITES:  0
# RETWEET COUNT:  39
# IMAGES: NONE
#
# ################################
#
# RT @IIITDelhi: Students of @midasIIITD lab won the best student poster award at 33rd @RealAAAI 2019 conference in Honolulu, Hawaii for the…
# DATE :  Mon Feb 04 10:58:53 +0000 2019
# FAVORITES:  0
# RETWEET COUNT:  4
# IMAGES: NONE
#
# ################################
#
# @RealAAAI 2019 summary for @midasIIITD.
# 1 paper in main conference, 1 paper in EAAI, 2 papers published in student abstract and poster sessions.
# We won the best student poster award.
# 6 researchers from MIDAS lab attended the conference.
# Got several interests for collaborations. https://t.co/JVo6pRMWL1
# DATE :  Sat Feb 02 05:05:16 +0000 2019
# FAVORITES:  7
# RETWEET COUNT:  3
# IMAGES:  1
#
# ################################
#
# @the_dhumketu @RealAAAI Congrats! Raghav, Kshitij, and @the_dhumketu for the best student poster award!
# Congrats @RatnRajiv @ponguru and Prof Roger Zimmermann for their guidance.
#
# Have a great time in Honolulu, Hawaii, USA.
# DATE :  Fri Feb 01 07:46:57 +0000 2019
# FAVORITES:  3
# RETWEET COUNT:  1
# IMAGES: NONE
#
# ################################
#
# Our paper titled, "Mind Your Language: Abuse and Offence Detection for Code-Switched Languages", won the best student poster award at 33rd @RealAAAI 2019 conference in Honolulu, Hawaii, USA.
#
# Congratulations authors! Raghav, Kshitij, @the_dhumketu, @ponguru, and Roger.
#
# #AAAI19 https://t.co/e5lFJhb6bi
# DATE :  Fri Feb 01 07:30:53 +0000 2019
# FAVORITES:  24
# RETWEET COUNT:  3
# IMAGES:  1
#
# ################################
#
# RT @PeterMartigny: Very interesting talk by @ChenguangZhu2 at the @stanfordnlp seminar on SDNet, a new architecture for conversational ques…
# DATE :  Fri Feb 01 03:15:27 +0000 2019
# FAVORITES:  0
# RETWEET COUNT:  8
# IMAGES: NONE
#
# ################################
#
# RT @NilayShri: @midasIIITD @RatnRajiv
# @the_dhumketu
# https://t.co/PkUa18lF8p
# DATE :  Fri Feb 01 03:13:23 +0000 2019
# FAVORITES:  0
# RETWEET COUNT:  2
# IMAGES: NONE
#
# ################################
#
# CFP for @ACMMM19 has been posted on WikiCFP. Kindly share with your colleagues and submit your work to #ACMMM 2019.
#
# https://t.co/Kgti6H4W8g
#
# Please share, @IIITDelhi @iiit_hyderabad @precog_iiitd @iitdelhi @iitbombay @IITKgp @IITKanpur @_iitg @iiscbangalore @iitropar @lcs2iiitd
# DATE :  Thu Jan 31 06:57:04 +0000 2019
# FAVORITES:  1
# RETWEET COUNT:  1
# IMAGES: NONE
#
# ################################
#
# @midasIIITD Lab is pleased to share our novel work titled, Harnessing GANs for Addition of New Classes in VSR (https://t.co/SdFNLNP2PR).
#
# We present a novel approach to low-shot learning that uses the idea of imagination over unseen classes in a classification problem setting.
# DATE :  Thu Jan 31 05:50:19 +0000 2019
# FAVORITES:  4
# RETWEET COUNT:  2
# IMAGES: NONE
#
# ################################
#
# RT @RatnRajiv: If you are attending @RealAAAI and liked our work, Lipper, for speech reconstruction from silent videos using lipreading the…
# DATE :  Thu Jan 31 05:32:43 +0000 2019
# FAVORITES:  0
# RETWEET COUNT:  2
# IMAGES: NONE
#
# ################################
#
# RT @RatnRajiv: Great to be part of this year's accepted papers at @RealAAAI from India. Out of 25 papers from India, 6 from @IIITDelhi.
# Co…
# DATE :  Wed Jan 30 19:46:11 +0000 2019
# FAVORITES:  0
# RETWEET COUNT:  2
# IMAGES: NONE
#
# ################################
#
# RT @MIT: Want to squelch fake news? Let the readers take charge https://t.co/Jusr6TMUse https://t.co/KDHmFDP9aE
# DATE :  Wed Jan 30 17:18:40 +0000 2019
# FAVORITES:  0
# RETWEET COUNT:  11
# IMAGES:  1
#
# ################################
#
# If you are attending @RealAAAI 2019 at Honolulu, Hawaii, USA then attend our talk in the Student Abstract Session for very interesting work on speech reconstruction from silent videos based on lipreading.
#
# It is one of the first works of this kind.
# Looking forward to seeing you https://t.co/rODmBKSONr
# DATE :  Wed Jan 30 05:00:29 +0000 2019
# FAVORITES:  3
# RETWEET COUNT:  1
# IMAGES:  1
#
# ################################
#
# If you are attending @RealAAAI 2019 then visit following sessions for our papers.
#
# 3. Lipper: Synthesizing Thy Speech using Multi-View Lipreading
# - Time: Thursday, Main Paper Session
# - Authors: @the_dhumketu, Rohit, Salik, @RatnRajiv, Yifang, and Roger
#
# 3/3
# DATE :  Tue Jan 29 19:42:10 +0000 2019
# FAVORITES:  5
# RETWEET COUNT:  2
# IMAGES: NONE
#
# ################################
#
# If you are attending @RealAAAI 2019 then visit following sessions for our papers.
#
# 2. Lipper: Speaker Independent Speech Synthesis using Multi-View Lipreading
# - Time: Wednesday, Student Abstract Session
# - Authors: Salik, @the_dhumketu, Rohit, Swati, @RatnRajiv, and Roger
#
# 2/3
# DATE :  Tue Jan 29 19:39:29 +0000 2019
# FAVORITES:  3
# RETWEET COUNT:  1
# IMAGES: NONE
#
# ################################
#
# If you are attending @RealAAAI 2019 then visit following sessions for our papers.
#
# 1. Mind Your Language: Abuse and Offense Detection on Code-Switched Languages
# - Time: Tuesday, Student Abstract Session (SAS)
# - Authors: Raghav, @the_dhumketu, Kshitij, @RatnRajiv, PK, Roger
#
# 1/3
# DATE :  Tue Jan 29 19:31:35 +0000 2019
# FAVORITES:  2
# RETWEET COUNT:  1
# IMAGES: NONE
#
# ################################
#
# @TechAtBloomberg @debanjanbhucs It is a great experience to work with @debanjanbhucs.
# @midasIIITD looks forward to many more such works with Bloomberg.
# DATE :  Tue Jan 29 18:05:01 +0000 2019
# FAVORITES:  5
# RETWEET COUNT:  2
# IMAGES: NONE
#
# ################################
#
# RT @TechAtBloomberg: Learn more about the collaborative efforts of researchers @debanjanbhucs &amp; Daniel Preoţiuc-Pietro w/ academics around…
# DATE :  Tue Jan 29 18:03:31 +0000 2019
# FAVORITES:  0
# RETWEET COUNT:  5
# IMAGES: NONE
#
# ################################
#
# RT @debanjanbhucs: We as researchers working at Bloomberg also get opportunities to collaborate with academia. Here are the outcomes of two…
# DATE :  Tue Jan 29 17:52:23 +0000 2019
# FAVORITES:  0
# RETWEET COUNT:  2
# IMAGES: NONE
#
# ################################
#
# RT @kdnuggets: 7 Steps to Mastering Basic Machine Learning with Python — 2019 Edition
#  https://t.co/yZExGjOVWH https://t.co/sJC8p2kTyp
# DATE :  Tue Jan 29 14:52:24 +0000 2019
# FAVORITES:  0
# RETWEET COUNT:  33
# IMAGES:  1
#
# ################################
#
# @TechAtBloomberg @debanjanbhucs @IIITDelhi @RatnRajiv Congrats, team @midasIIITD! https://t.co/ncsgSUusUb
# DATE :  Tue Jan 29 05:17:27 +0000 2019
# FAVORITES:  3
# RETWEET COUNT:  1
# IMAGES:  1
#
# ################################
#
# RT @TechAtBloomberg: #Textanalytics researcher @debanjanbhucs joins @IIITDelhi's @RatnRajiv &amp; other co-authors to present "Get IT Scored us…
# DATE :  Tue Jan 29 04:40:47 +0000 2019
# FAVORITES:  0
# RETWEET COUNT:  5
# IMAGES: NONE
#
# ################################
#
# RT @kdnuggets: Top 16 #OpenSource #DeepLearning Libraries and Platforms #KDN https://t.co/TycxmMSCWs
# DATE :  Mon Jan 28 12:11:29 +0000 2019
# FAVORITES:  0
# RETWEET COUNT:  8
# IMAGES: NONE
#
# ################################
#
# RT @Princeton: Using data from more than 6,000 patients, @EPrinceton researchers applied #machinelearning methods to design a system that c…
# DATE :  Mon Jan 28 12:11:13 +0000 2019
# FAVORITES:  0
# RETWEET COUNT:  18
# IMAGES: NONE
#
# ################################
#
# RT @CornellBirds: In 1929 Cornell Lab founder Arthur Allen made the very first recordings of wild birds. Follow @MacaulayLibrary as they sh…
# DATE :  Mon Jan 28 12:10:37 +0000 2019
# FAVORITES:  0
# RETWEET COUNT:  68
# IMAGES: NONE
#
# ################################
#
# RT @seb_ruder: Natural Questions: A new QA dataset consisting of 300,000+ naturally occurring questions (posed to Google search) with human…
# DATE :  Fri Jan 25 08:56:54 +0000 2019
# FAVORITES:  0
# RETWEET COUNT:  141
# IMAGES: NONE
#
# ################################
#
# RT @kdnuggets: 10 More #Free Must-Read #Books for #MachineLearning and #DataScience #KDN https://t.co/EtMyAJFl6d
# DATE :  Thu Jan 24 15:43:25 +0000 2019
# FAVORITES:  0
# RETWEET COUNT:  23
# IMAGES: NONE
#
# ################################
#
# RT @kdnuggets: How to build an API for a machine learning model in 5 minutes using Flask https://t.co/VFN7NmCqTu https://t.co/oZ8rXEGM5w
# DATE :  Thu Jan 24 15:42:59 +0000 2019
# FAVORITES:  0
# RETWEET COUNT:  25
# IMAGES:  1
#
# ################################
#
# @ACMMM19 @ACM @abhinavdhall consider submitting your proposal.
# DATE :  Wed Jan 23 10:24:14 +0000 2019
# FAVORITES:  0
# RETWEET COUNT:  0
# IMAGES: NONE
#
# ################################
#
# RT @ACMMM19: Jump start your @ACM #Multimedia workshop submission... First workshop titles are now online https://t.co/S9ZSaJTH1a But also…
# DATE :  Wed Jan 23 10:23:34 +0000 2019
# FAVORITES:  0
# RETWEET COUNT:  10
# IMAGES: NONE
#
# ################################
#
# @NUSComputing Congratulations! Yaman @the_dhumketu , Roger, Yifang, @RatnRajiv, Rohit, and Salik.
# DATE :  Tue Jan 22 14:04:40 +0000 2019
# FAVORITES:  1
# RETWEET COUNT:  1
# IMAGES: NONE
#
# ################################
#
# ⚡️ “Achievements”
#
# https://t.co/LvZt1GTY4C
# DATE :  Tue Jan 22 14:02:51 +0000 2019
# FAVORITES:  3
# RETWEET COUNT:  1
# IMAGES: NONE
#
# ################################
#
# RT @NUSComputing: A/P Roger Zimmermann and his collaborators from IIIT Delhi developed a lipreading system that produces audio from lip mov…
# DATE :  Tue Jan 22 13:58:08 +0000 2019
# FAVORITES:  0
# RETWEET COUNT:  2
# IMAGES: NONE
#
# ################################
#
# Welcome one member to our @midasIIITD family, SkyWalker.
# It will strengthen our team with Falcon.
#
# #midas #server #falcon #skywalker https://t.co/u6YOBaJ7DB
# DATE :  Mon Jan 21 16:29:31 +0000 2019
# FAVORITES:  9
# RETWEET COUNT:  1
# IMAGES:  1
#
# ################################
#
# Dr @RatnRajiv Shah delivered a research talk in the National Symposium on Natural Languages Processing and Artificial Intelligence at the Manipal University Jaipur. He discussed different multimedia systems for society and healthcare which @midasIIITD lab is currently working on. https://t.co/cVAGyk9xAs
# DATE :  Mon Jan 21 15:19:33 +0000 2019
# FAVORITES:  6
# RETWEET COUNT:  2
# IMAGES:  1
#
# ################################
#
# RT @Scott__Hubbard: Don't miss this new article from @ted_dunning, who presents practical methods for near real-time monitoring of machine…
# DATE :  Mon Jan 21 09:33:03 +0000 2019
# FAVORITES:  0
# RETWEET COUNT:  9
# IMAGES: NONE
#
# ################################
#
# RT @kaggle: Stuck inside with stir-crazy kids? 😫🤒😵Check out these downloadable machine learning projects designed for kids aged 8-16 👉https…
# DATE :  Mon Jan 21 09:32:03 +0000 2019
# FAVORITES:  0
# RETWEET COUNT:  37
# IMAGES: NONE
#
# ################################
#
# @Princeton @nyuniversity @nytimes Team @midasIIITD, do we have the same trend in India?
# DATE :  Mon Jan 21 06:54:14 +0000 2019
# FAVORITES:  0
# RETWEET COUNT:  0
# IMAGES: NONE
#
# ################################
#
# RT @Harvard: Researchers find connections between worry and the development of heart disease https://t.co/yQ4miy8DHI
# DATE :  Sun Jan 20 05:49:19 +0000 2019
# FAVORITES:  0
# RETWEET COUNT:  77
# IMAGES: NONE
#
# ################################
#
# RT @Stanford: Researchers across Stanford are exploring ways to predict and prevent preterm births, and to improve care for the highest-ris…
# DATE :  Sat Jan 19 18:15:35 +0000 2019
# FAVORITES:  0
# RETWEET COUNT:  8
# IMAGES: NONE
#
# ################################
#
# Meet our members of @midasIIITD .
#
# https://t.co/2PFbtoDtDR
#
# We welcome new members to our group.
#
# MIDAS is a group of researchers at IIIT-Delhi who study, analyze, and build different multimedia systems for society leveraging multimodal information.
#
# #multimedia #research #lab
# DATE :  Sat Jan 19 09:59:16 +0000 2019
# FAVORITES:  7
# RETWEET COUNT:  2
# IMAGES: NONE
#
# ################################
#
# RT @kdnuggets: How to Monitor Machine Learning Models in Real-Time https://t.co/9UpYVzlQWI https://t.co/9lK9eoOVWe
# DATE :  Sat Jan 19 03:27:33 +0000 2019
# FAVORITES:  0
# RETWEET COUNT:  9
# IMAGES:  1
#
# ################################
#
# Congratulations! @Leomi7 @ashualloy @RatnRajiv Ayush, Himanshu, Aditya, Deepanshu, @isarth23 @rgrgrajat1
# DATE :  Fri Jan 18 10:25:41 +0000 2019
# FAVORITES:  6
# RETWEET COUNT:  0
# IMAGES: NONE
#
# ################################
#
# RT @jasonbaumgartne: #Pushshift is happy to announce a new dataset for your ML / NLP / Research pleasure -- Data for over 340+ Stackexchang…
# DATE :  Fri Jan 18 10:17:02 +0000 2019
# FAVORITES:  0
# RETWEET COUNT:  19
# IMAGES: NONE
#
# ################################
#
# Proceedings of FIRE 2018 is online now at https://t.co/vzLpwVp1Qb
# Our 4 papers are:
# 1. Fully Automatic Approach to Identify Factual or Fact-checkable Tweets
# 2. Multilingual Author Profiling from SMS
# 3. NMT based Tamil Translation
# 4. Named Entity Recognition for Indian Languages
# DATE :  Fri Jan 18 10:16:26 +0000 2019
# FAVORITES:  10
# RETWEET COUNT:  2
# IMAGES: NONE
#
# ################################
#
# RT @hseas: Only 20 percent of pediatric cancer patients in lower- and middle-income countries will survive. Engineering students partnered…
# DATE :  Thu Jan 17 04:04:16 +0000 2019
# FAVORITES:  0
# RETWEET COUNT:  27
# IMAGES: NONE
#
# ################################
#
# RT @Cornell: Can virtual reality transform medicine? Psychologist JoAnn Difede @WeillCornell began using #VR with soldiers and survivors fr…
# DATE :  Thu Jan 17 04:03:55 +0000 2019
# FAVORITES:  0
# RETWEET COUNT:  11
# IMAGES: NONE
#
# ################################
#
# RT @kdnuggets: Explainable Artificial Intelligence https://t.co/rllNxnm73U https://t.co/mAYFPMJF8P
# DATE :  Sun Jan 13 16:45:48 +0000 2019
# FAVORITES:  0
# RETWEET COUNT:  20
# IMAGES:  1
#
# ################################
#
# @abhinavdhall @RatnRajiv Emailed you.
# DATE :  Sun Jan 13 16:40:46 +0000 2019
# FAVORITES:  0
# RETWEET COUNT:  0
# IMAGES: NONE
#
# ################################
#
# RT @kdnuggets: A comprehensive list of #MachineLearning Resources: Open Courses, Textbooks, #Tutorials, Cheat Sheets and more #KDN https://…
# DATE :  Sun Jan 13 16:03:25 +0000 2019
# FAVORITES:  0
# RETWEET COUNT:  39
# IMAGES: NONE
#
# ################################
#
# Call for Book Chapter- Springer- Deep learning based approaches for sentiment analysis. Contact for more details.
#
# Important Dates:
#
# Abstract: Jan 15, 2019
# Notification: Jan 31
# Full chapter:  April 15
# First review: May 15
# Final notification: June 30
# Camera Ready: July 15
# DATE :  Sun Jan 13 07:19:19 +0000 2019
# FAVORITES:  6
# RETWEET COUNT:  1
# IMAGES: NONE
#
# ################################
#
# RT @Stanford: The average woman is exposed to four medications during her pregnancy and over 80 percent of medications haven’t been studied…
# DATE :  Sat Jan 12 14:37:07 +0000 2019
# FAVORITES:  0
# RETWEET COUNT:  48
# IMAGES: NONE
#
# ################################
#
# @harvardmed @Harvard Another interesting direction to our previous work @MADAIguy @Leomi7
# DATE :  Thu Jan 10 08:51:20 +0000 2019
# FAVORITES:  1
# RETWEET COUNT:  0
# IMAGES: NONE
#
# ################################
#
# RT @harvardmed: A first-of-its-kind strategy aims to improve outcomes for kidney cancer patients who are at high risk of recurrence followi…
# DATE :  Thu Jan 10 08:50:35 +0000 2019
# FAVORITES:  0
# RETWEET COUNT:  27
# IMAGES: NONE
#
# ################################
#
# RT @RatnRajiv: Fortunate to have appreciation from my former NUS professor, Dr. Terence Sim.
# He also appreciated our @RealAAAI
# 2019 paper o…
# DATE :  Thu Jan 10 08:48:17 +0000 2019
# FAVORITES:  0
# RETWEET COUNT:  3
# IMAGES: NONE
#
# ################################
#
# RT @Harvard: The study provides potential future targets for drug development to treat osteoporosis https://t.co/YhfrOovdbO
# DATE :  Wed Jan 09 02:05:06 +0000 2019
# FAVORITES:  0
# RETWEET COUNT:  9
# IMAGES: NONE
#
# ################################
#
# RT @UniofOxford: In the final episode of series one of our Futuremakers podcast series, hear from Professor Sir @Nigel_Shadbolt on where th…
# DATE :  Mon Jan 07 09:05:12 +0000 2019
# FAVORITES:  0
# RETWEET COUNT:  16
# IMAGES: NONE
#
# ################################
#
# @ACMMM19: Call for Workshop Proposals
#
# Deadline: Friday 15 February 2019
#
# https://t.co/vpdx97ucNP
#
# #ACMMM19 #Multimedia #Research #Nice #France
# DATE :  Sun Jan 06 12:54:06 +0000 2019
# FAVORITES:  1
# RETWEET COUNT:  0
# IMAGES: NONE
#
# ################################
#
# @ACMMM19: Call for Grand Challenge Proposals
#
# Deadline: Tuesday 8 January 2019
#
# Check more details at-  https://t.co/uT3bFAsjfU
#
# #ACMMM #Multimedia #Research #Nice
# DATE :  Sun Jan 06 04:29:25 +0000 2019
# FAVORITES:  1
# RETWEET COUNT:  0
# IMAGES: NONE
#
# ################################
#
# Since 1993, ACM Multimedia has been bringing together researchers and practitioners from academia and industry to present innovative research results and discuss recent advancements.
#
# Check @ACMMM19 website for more details:
# https://t.co/QroXuO8ZAV
#
# #ACMMM #Multimedia #Research
# DATE :  Sun Jan 06 04:09:54 +0000 2019
# FAVORITES:  5
# RETWEET COUNT:  1
# IMAGES: NONE
#
# ################################
#
# @ACMMM19 is structured around four themes (alphabetical):
#
# Engaging users with multimedia
# Multimedia experience
# Multimedia systems
# Understanding multimedia content
#
# Multimedia research focuses on integration of the multiple perspectives offered by different digital modalities.
# DATE :  Sun Jan 06 04:07:29 +0000 2019
# FAVORITES:  1
# RETWEET COUNT:  0
# IMAGES: NONE
#
# ################################
#
# ACM Multimedia 2019: First Call for Papers/Call for Contributions
# @ACMMM19 is the premier international conference in the area of multimedia within the field of computer science.
# Details on the conference themes are available on the conference website:
# https://t.co/QroXuO8ZAV
# DATE :  Sun Jan 06 04:05:38 +0000 2019
# FAVORITES:  4
# RETWEET COUNT:  2
# IMAGES: NONE
#
# ################################
#
# RT @ACMMM19: Happy new year! 2019 started with a bang. Thanks to everyone working to help resolve the ACM webserver hack issues. Please wat…
# DATE :  Thu Jan 03 06:14:05 +0000 2019
# FAVORITES:  0
# RETWEET COUNT:  2
# IMAGES: NONE
#
# ################################
#
# You may follow @midasIIITD updates through following:
#
# Website: https://t.co/sPvbKhflKQ
# Facebook: https://t.co/yMDAL2pof0
# LinkedIn: https://t.co/ZPNNnLTi8Z
#
# We look forward to producing some groundbreaking work in 2019 which can help society through ML and Multimedia Processing.
# DATE :  Tue Jan 01 17:21:49 +0000 2019
# FAVORITES:  4
# RETWEET COUNT:  2
# IMAGES: NONE
#
# ################################
#
# Today, @midasIIITD completed one year at @IIITDelhi. In last one year, we have shown our strong presence in research communities of top-tier conferences and journals through our world-class research. This could not have been possible without the hard work of MIDAS researchers. https://t.co/zCdQr8Zfwe
# DATE :  Tue Jan 01 17:17:56 +0000 2019
# FAVORITES:  14
# RETWEET COUNT:  5
# IMAGES:  1
#
# ################################
#
# RT @debanjanbhucs: Happy anniversary to @midasIIITD . It surely has been a productive year for us and hope to see some ground breaking work…
# DATE :  Tue Jan 01 16:14:24 +0000 2019
# FAVORITES:  0
# RETWEET COUNT:  4
# IMAGES: NONE
#
# ################################
#
# Two Research Assistant (RA) positions are still open. Contact us if you are eligible and interested to work on the mentioned projects.
#
# PS: RAs are full-time jobs. Only apply if you have finished your studies.
# DATE :  Thu Dec 27 10:28:31 +0000 2018
# FAVORITES:  2
# RETWEET COUNT:  1
# IMAGES: NONE
#
# ################################
#
# Positions for two Research Assistants (RA) are still open at @midasIIITD. Interested candidates may send their CV at midas AT https://t.co/ey7h1zgmKD
# PS: RAs are full-time positions. Thus, only candidates who have finished their study are requested to apply.
# #MIDAS #Humonics #RA
# DATE :  Thu Dec 27 09:59:06 +0000 2018
# FAVORITES:  5
# RETWEET COUNT:  3
# IMAGES: NONE
#
# ################################
#
# RT @TCoolsIT: I wrote a blogpost on CoreNLP highlighting some of its functionality. If you want a quick dip before diving into the course,…
# DATE :  Thu Dec 27 02:33:58 +0000 2018
# FAVORITES:  0
# RETWEET COUNT:  12
# IMAGES: NONE
#
# ################################
#
# @RatnRajiv delivered a research talk at the Central Research Laboratories of NEC Corporation, Japan. He discussed several multimedia systems for society and healthcare. He had interesting pre and post-talk discussions on multimedia systems for cybersecurity that can help society. https://t.co/itWHzv0ias
# DATE :  Wed Dec 26 09:41:04 +0000 2018
# FAVORITES:  14
# RETWEET COUNT:  2
# IMAGES:  1
#
# ################################
#
# @midasIIITD look forward to work together. https://t.co/nrpf32ODo2
# DATE :  Tue Dec 25 04:15:15 +0000 2018
# FAVORITES:  1
# RETWEET COUNT:  0
# IMAGES: NONE
#
# ################################
#
# @the_dhumketu @punnibhai @Hitkul_, FYI. https://t.co/yZb9mdr6IB
# DATE :  Tue Dec 25 03:00:21 +0000 2018
# FAVORITES:  2
# RETWEET COUNT:  1
# IMAGES: NONE
#
# ################################
#
# RT @iiit_hyderabad: KCIS Distinguished Lecture by Andrew Zisserman on Learning from Sight and Sound. Three-time Marr Prize winner Zisserman…
# DATE :  Mon Dec 24 07:39:21 +0000 2018
# FAVORITES:  0
# RETWEET COUNT:  12
# IMAGES: NONE
#
# ################################
#
# RT @StanfordAILab: Our latest blog post is out!
#
# Check it out for a recording and summary of highlights from the event "AI and the Future…
# DATE :  Fri Dec 21 03:50:39 +0000 2018
# FAVORITES:  0
# RETWEET COUNT:  32
# IMAGES: NONE
#
# ################################
#
# RT @medialab: In two new papers, @PratikShahPhD and collaborators present novel #AI and machine learning methods to improve diagnosis at th…
# DATE :  Thu Dec 20 18:05:35 +0000 2018
# FAVORITES:  0
# RETWEET COUNT:  8
# IMAGES: NONE
#
# ################################
#
# RT @RatnRajiv: Wonderful get together with our NII colleagues. Prior to that we had a wonderful talk with Prof Chua Tat-Seng from National…
# DATE :  Thu Dec 20 06:14:52 +0000 2018
# FAVORITES:  0
# RETWEET COUNT:  3
# IMAGES: NONE
#
# ################################
#
# @ACMMM19 is the premier international conference in the area of multimedia within the field of computer science. Multimedia research focuses on integration of the multiple perspectives offered by different digital modalities including images, text, video, music, and sensor data. https://t.co/8RPzQHnB34
# DATE :  Wed Dec 19 02:16:31 +0000 2018
# FAVORITES:  2
# RETWEET COUNT:  3
# IMAGES:  1
#
# ################################
#
# Feel free to contact us if you have any query on @ACMMM19. We look forward to your submissions to ACM Multimedia conference 2019.
#
# Check more details on submission at https://t.co/xA2jk0KPPC
#
# #Multimedia #Research #ACMMM2019 #Nice
# DATE :  Tue Dec 18 14:42:27 +0000 2018
# FAVORITES:  3
# RETWEET COUNT:  2
# IMAGES: NONE
#
# ################################
#
# @NilayShri @RatnRajiv @ACMMM19 Looking forward to your paper to @ACMMM19.
# DATE :  Tue Dec 18 14:27:12 +0000 2018
# FAVORITES:  3
# RETWEET COUNT:  0
# IMAGES: NONE
#
# ################################
#
# @midasIIITD head, Dr. @RatnRajiv appointed as one of the publicity co-chairs for @ACMMM19. ACM Multimedia is the premier conference for Multimedia research. We look forward to supporting a large number of submissions to https://t.co/QroXuO8ZAV this year from India.
#
# #Multimedia
# DATE :  Tue Dec 18 14:15:32 +0000 2018
# FAVORITES:  12
# RETWEET COUNT:  5
# IMAGES: NONE
#
# ################################
#
# @ACMMM19 @the_dhumketu fill the volunteer form for reviewer.
# DATE :  Tue Dec 18 12:34:10 +0000 2018
# FAVORITES:  1
# RETWEET COUNT:  0
# IMAGES: NONE
#
# ################################
#
# RT @ACMMM19: New in 2019! Volunteer to serve as ACM Multimedia Area Chair or Reviewer. Please provide information on your qualifications in…
# DATE :  Tue Dec 18 12:33:42 +0000 2018
# FAVORITES:  0
# RETWEET COUNT:  7
# IMAGES: NONE
#
# ################################
#
# RT @IIITDelhi: Congratulations! authors Yaman @the_dhumketu, @RatnRajiv, and team @midasIIITD for winning the best poster runner-up at 20th…
# DATE :  Tue Dec 18 04:38:35 +0000 2018
# FAVORITES:  0
# RETWEET COUNT:  3
# IMAGES: NONE
#
# ################################
#
# Best wishes to @midasIIITD students @_himanshu0113, @Hitkul_, and Shivangi on starting their research internship at National Institute of Informatics (NII), Tokyo, Japan. They will be working with our collaborators Prof Yu and Prof Satoh for six months.
#
# #internship #tokyo #nii https://t.co/JwWA8D9uHH
# DATE :  Mon Dec 17 16:57:00 +0000 2018
# FAVORITES:  14
# RETWEET COUNT:  4
# IMAGES:  1
#
# ################################
#
# RT @MIT: Computer model could improve human-machine interaction, provide insight into how children learn language. https://t.co/ToQo6GTMcG…
# DATE :  Mon Dec 17 15:05:44 +0000 2018
# FAVORITES:  0
# RETWEET COUNT:  20
# IMAGES: NONE
#
# ################################
#
# RT @kdnuggets: Great @Wired interview with Geoff #Hinton on #AI risks, explanation, Graphcore chips, brain vs neural nets, and why there wi…
# DATE :  Mon Dec 17 14:37:00 +0000 2018
# FAVORITES:  0
# RETWEET COUNT:  20
# IMAGES: NONE
#
# ################################
#
# ...
# A great scope to work on this dataset.
# DATE :  Thu Aug 23 03:31:55 +0000 2018
# FAVORITES:  1
# RETWEET COUNT:  0
# IMAGES: NONE
#
# ################################
#
# @danqi_chen @stanfordnlp FYI @the_dhumketu
# DATE :  Wed Aug 22 19:22:16 +0000 2018
# FAVORITES:  1
# RETWEET COUNT:  0
# IMAGES: NONE
#
# ################################
#
# RT @kdnuggets: Awesome #DeepLearning: Most Cited #DeepLearning Papers #KDN https://t.co/szGieAzboH
# DATE :  Wed Aug 22 16:11:43 +0000 2018
# FAVORITES:  0
# RETWEET COUNT:  33
# IMAGES: NONE
#
# ################################
#
# RT @stanfordnlp: People usually get information from others in a multi-turn conversation. To approach this, we’ve released CoQA 🍃—A Convers…
# DATE :  Wed Aug 22 15:50:12 +0000 2018
# FAVORITES:  0
# RETWEET COUNT:  233
# IMAGES: NONE
#
# ################################
#
# Team @midasIIITD looking forward to with CDNM. https://t.co/h4roiaL1X6
# DATE :  Wed Aug 22 12:53:38 +0000 2018
# FAVORITES:  4
# RETWEET COUNT:  1
# IMAGES: NONE
#
# ################################
#
# RT @VeredShwartz: After 3 years of blogging about NLP, with the goal of writing in simple words that non-experts can understand, I finally…
# DATE :  Wed Aug 22 05:35:37 +0000 2018
# FAVORITES:  0
# RETWEET COUNT:  61
# IMAGES: NONE
#
# ################################
#
# RT @msisodia: With immense ambition &amp; hope, inaugurated the sprawling @IIITDelhi Phase 2 Campus with Hon'ble CM @ArvindKejriwal
#
# The total…
# DATE :  Wed Aug 22 04:56:37 +0000 2018
# FAVORITES:  0
# RETWEET COUNT:  496
# IMAGES: NONE
#
# ################################
#
# RT @goodfellow_ian: Video-to-video translation with conditional GANs https://t.co/DDmRSTkpri
# DATE :  Wed Aug 22 04:56:22 +0000 2018
# FAVORITES:  0
# RETWEET COUNT:  87
# IMAGES: NONE
#
# ################################
#
# RT @kaggle: RT @afshinea 🔥Set of illustrated Machine Learning cheat sheets from Stanford's CS 229 class:
# Deep Learning: https://t.co/BNQ7Fp…
# DATE :  Wed Aug 22 04:56:17 +0000 2018
# FAVORITES:  0
# RETWEET COUNT:  554
# IMAGES: NONE
#
# ################################
#
# RT @jain49: Beginning to understand what we eat better. Next, controlling it through engineering. #FoodComputing https://t.co/PpMwnqFvak vi…
# DATE :  Mon Aug 20 05:41:16 +0000 2018
# FAVORITES:  0
# RETWEET COUNT:  1
# IMAGES: NONE
#
# ################################
#
# Our paper titled, "IceBreaker: Solving Cold Start Problem for Video
# Recommendation Engines", is now available on Arxiv.
#
# https://t.co/zuNS7DQ6MY
#
# #MIDAS #Arxiv #IIITD #IceBreaker #VideoRecommendation
# DATE :  Mon Aug 20 04:32:09 +0000 2018
# FAVORITES:  3
# RETWEET COUNT:  1
# IMAGES: NONE
#
# ################################
#
# RT @mr2amc: Call for papers: MR2AMC 2018, Taichung, Taiwan.
#
# https://t.co/gBhtnsyUk3
# DATE :  Mon Aug 20 03:51:43 +0000 2018
# FAVORITES:  0
# RETWEET COUNT:  1
# IMAGES: NONE
#
# ################################
#
# Our paper titled, "Neural Machine Translation for English-Tamil", is got accepted to the third Conference on Machine Translation (WMT18) in EMNLP 2018.
#
# #EMNLP #NLP #MT #MIDAS
# DATE :  Sun Aug 19 09:19:12 +0000 2018
# FAVORITES:  9
# RETWEET COUNT:  0
# IMAGES: NONE
#
# ################################
#
# RT @mr2amc: Team @midasIIITD, please spread CFP for @mr2amc
#
# #ISM #MR2AMC #IEEE #MIDAS https://t.co/D2ZJjYR8N4
# DATE :  Sat Aug 18 19:04:18 +0000 2018
# FAVORITES:  0
# RETWEET COUNT:  3
# IMAGES:  1
#
# ################################
#
# RT @mr2amc: Our paper submission system is ready on EasyChair for @mr2amc
#
# https://t.co/kMfbLOcz6x
#
# You may submit your original contribut…
# DATE :  Sat Aug 18 17:19:21 +0000 2018
# FAVORITES:  0
# RETWEET COUNT:  3
# IMAGES: NONE
#
# ################################
#
# RT @NurtureAI: How do you choose the hyperparameters of an NN model? While current methods revolve around trial and error, this becomes inf…
# DATE :  Sat Aug 18 03:55:34 +0000 2018
# FAVORITES:  0
# RETWEET COUNT:  5
# IMAGES: NONE
#
# ################################
#
# RT @kdnuggets: Diving Deep into Deepfakes https://t.co/gM5xM4pMkz https://t.co/o969Jpeuwr
# DATE :  Thu Aug 16 06:13:04 +0000 2018
# FAVORITES:  0
# RETWEET COUNT:  12
# IMAGES:  1
#
# ################################
#
# Congratulations @midasIIITD @IIITDelhi interns, Deepanshu, Meghna, and Ashutosh for getting their paper accepted to the MAPonSMS'18 task of the 10th Forum for Information Retrieval Evaluation (FIRE) conference. Paper will be published in the Springer LNCS. #MIDAS #Achievment
# DATE :  Thu Aug 16 04:30:12 +0000 2018
# FAVORITES:  7
# RETWEET COUNT:  3
# IMAGES: NONE
#
# ################################
#
# RT @jain49: This is magic. In fact, more than magic, real transformation. https://t.co/tQbbb8Ka36
# DATE :  Wed Aug 15 14:38:37 +0000 2018
# FAVORITES:  0
# RETWEET COUNT:  1
# IMAGES: NONE
#
# ################################
#
# RT @kdnuggets: The Best Metric to Measure Accuracy of Classification Models #KDN https://t.co/RBFTGnKr5M
# DATE :  Wed Aug 15 14:37:22 +0000 2018
# FAVORITES:  0
# RETWEET COUNT:  6
# IMAGES: NONE
#
# ################################
#
# RT @kdnuggets: KDnuggets 18:n31: Top 10 roles in #AI and #datascience; Github Data Science Spotlight: #Python tools for #MachineLearning ht…
# DATE :  Wed Aug 15 14:36:08 +0000 2018
# FAVORITES:  0
# RETWEET COUNT:  6
# IMAGES: NONE
#
# ################################
#
# RT @ponguru: Looking for ideas / projects in #privacy and #security in #socialnetwork? Here is a list of ideas that you can explore https:/…
# DATE :  Wed Aug 15 09:03:25 +0000 2018
# FAVORITES:  0
# RETWEET COUNT:  4
# IMAGES: NONE
#
# ################################
#
# RT @coling2018: #COLING2018 proceedings are now in the ACL Anthology! https://t.co/75kJ0btl3M
#
# #nlproc #linguistics Check out those multili…
# DATE :  Mon Aug 13 10:48:07 +0000 2018
# FAVORITES:  0
# RETWEET COUNT:  28
# IMAGES: NONE
#
# ################################
#
# Very interesting! We at @midasIIITD, also doing some work on @DigitalHealth. Hope to present them in upcoming conferences. https://t.co/jx21cAdqoE
# DATE :  Sun Aug 12 15:07:30 +0000 2018
# FAVORITES:  3
# RETWEET COUNT:  1
# IMAGES: NONE
#
# ################################
#
# RT @kdnuggets: GitHub Python Data Science Spotlight: AutoML, NLP, Visualization, ML Workflows https://t.co/83nUhUzxF6 https://t.co/213EnP8x…
# DATE :  Sun Aug 12 14:19:37 +0000 2018
# FAVORITES:  0
# RETWEET COUNT:  45
# IMAGES: NONE
#
# ################################
#
# RT @mr2amc: @mr2amc will be organized by Prof @RatnRajiv and A V Subramanyam (@IIITDelhi ), Prof Roger Zimmermann and Yifang Yin (@NUSCompu…
# DATE :  Sun Aug 12 13:11:04 +0000 2018
# FAVORITES:  0
# RETWEET COUNT:  2
# IMAGES: NONE
#
# ################################
#
# RT @mr2amc: Our workshop proposal on Multimodal Representation, Retrieval, and Analysis of Multimedia Content in Social Media (MR2AMC) http…
# DATE :  Sun Aug 12 09:07:16 +0000 2018
# FAVORITES:  0
# RETWEET COUNT:  2
# IMAGES: NONE
#
# ################################
#
# NLP's ImageNet moment has arrived » https://t.co/miZDIXKpq5 #natural language processing #nlp #transfer learning
# DATE :  Sun Aug 12 04:29:38 +0000 2018
# FAVORITES:  2
# RETWEET COUNT:  0
# IMAGES: NONE
#
# ################################
#
# @soujanyaporia @nlp Congrats Dr. @soujanyaporia
# DATE :  Sat Aug 11 08:48:40 +0000 2018
# FAVORITES:  1
# RETWEET COUNT:  0
# IMAGES: NONE
#
# ################################
#
# RT @kdnuggets: Ultimate Guide to Getting Started with Tensorflow https://t.co/tWpYBsmbG5 https://t.co/jXi4GK97mX
# DATE :  Thu Aug 09 10:17:53 +0000 2018
# FAVORITES:  0
# RETWEET COUNT:  111
# IMAGES:  1
#
# ################################
#
# RT @TensorFlow: TensorFlow 1.10.0 has been released! Please see the full release notes for details on added features and changes ↓ https://…
# DATE :  Thu Aug 09 05:59:57 +0000 2018
# FAVORITES:  0
# RETWEET COUNT:  265
# IMAGES: NONE
#
# ################################
#
# @midasIIITD is looking for motivated IIITD MTech students who have an interest in research and deep learning techniques.
# If you have plans for doing Ph.D. in near future then you may consider pursuing your MTech thesis at MIDAS. @IIITDelhi
# DATE :  Wed Aug 08 11:30:56 +0000 2018
# FAVORITES:  2
# RETWEET COUNT:  1
# IMAGES: NONE
#
# ################################
#
# @IIITDelhi @ponguru @RatnRajiv The results of @midasIIITD are as follows https://t.co/I8bOPaJSQv
# DATE :  Wed Aug 08 05:53:48 +0000 2018
# FAVORITES:  3
# RETWEET COUNT:  1
# IMAGES:  1
#
# ################################
#
# RT @IIITDelhi: @midasIIITD has secured rank 1 in the IRMiDis challenge of the 10th FIRE 2018 conference. Congratulations MIDAS interns, Sak…
# DATE :  Wed Aug 08 05:45:58 +0000 2018
# FAVORITES:  0
# RETWEET COUNT:  1
# IMAGES: NONE
#
# ################################
#
# RT @kdnuggets: Comparison of Top 6 Python NLP Libraries https://t.co/3ubomIUh4N https://t.co/KgP6R9mZsD
# DATE :  Tue Aug 07 07:16:33 +0000 2018
# FAVORITES:  0
# RETWEET COUNT:  40
# IMAGES:  1
#
# ################################
#
# Check more details of the 20th IEEE International Symposium on Multimedia (ISM) conference at https://t.co/wMIaXBfCYR.
#  It is an international forum for researchers to exchange information regarding advances in the state of the art and practice of multimedia computing.
# #MR2AMC
# DATE :  Tue Aug 07 02:05:12 +0000 2018
# FAVORITES:  1
# RETWEET COUNT:  1
# IMAGES: NONE
#
# ################################
#
# MR2AMC@ISM 2018 will be organized by @RatnRajiv (@midasIIITD), @debanjanbhucs (@TechAtBloomberg), Yifang Yin (@NUSComputing), and @soujanyaporia (@NTUsg). Thanks to Prof Roger Zimmermann (NUS) for being the honorary chair for the workshop.
# #ISM2018 #IEEE #MIDAS @IIITDelhi 2/2
# DATE :  Tue Aug 07 01:58:49 +0000 2018
# FAVORITES:  1
# RETWEET COUNT:  1
# IMAGES: NONE
#
# ################################
#
# Our workshop proposal named, "MR2AMC: Multimodal Representation,
# Retrieval, and Analysis of Multimedia Content in Social Media", has been accepted to the 20th IEEE International Symposium on Multimedia (ISM) conference. Looking forward to your contributions.
# #MIDAS #ISM2018  1/2
# DATE :  Tue Aug 07 01:50:33 +0000 2018
# FAVORITES:  1
# RETWEET COUNT:  1
# IMAGES: NONE
#
# ################################
#
# @NUSComputing Congratulations Abdelhak and Prof Zimmermann.
# DATE :  Mon Aug 06 17:48:23 +0000 2018
# FAVORITES:  0
# RETWEET COUNT:  0
# IMAGES: NONE
#
# ################################
#
# RT @goodfellow_ian: One of the most anticipated GAN names now taken: paGAN. https://t.co/ifUgy40O8t https://t.co/NvxKDwEMZz
# DATE :  Mon Aug 06 17:46:59 +0000 2018
# FAVORITES:  0
# RETWEET COUNT:  103
# IMAGES:  1
#
# ################################
#
# @the_dhumketu Great to have you in @midasIIITD
# DATE :  Mon Aug 06 06:06:47 +0000 2018
# FAVORITES:  0
# RETWEET COUNT:  0
# IMAGES: NONE
#
# ################################
#
# Congratulation @soujanyaporia for being appointed as an Adjunct Faculty of @IIITDelhi. He will be working with team @midasIIITD in collaboration with Prof @RatnRajiv on several interesting projects. Welcome to MIDAS and IIITD family. #NTU #IIITD #MIDAS #Collaboration
# DATE :  Fri Aug 03 05:56:33 +0000 2018
# FAVORITES:  6
# RETWEET COUNT:  1
# IMAGES: NONE
#
# ################################
#
# @IIITDelhi @the_dhumketu Thanks team @midasIIITD https://t.co/2WvhaHBq3h
# DATE :  Wed Aug 01 11:47:15 +0000 2018
# FAVORITES:  5
# RETWEET COUNT:  1
# IMAGES:  1
#
# ################################
#
# RT @IIITDelhi: Congratulations @midasIIITD intern @the_dhumketu for getting his paper titled,"Harnessing AI for Speech Reconstruction using…
# DATE :  Wed Aug 01 11:20:07 +0000 2018
# FAVORITES:  0
# RETWEET COUNT:  4
# IMAGES: NONE
#
# ################################
#
# RT @learning_pt: Profile of the 5 Indian undergrads admitted to MIT for 2018-2022 session.
# Note, how they grabbed the Linguistics Olympiad…
# DATE :  Wed Aug 01 05:06:47 +0000 2018
# FAVORITES:  0
# RETWEET COUNT:  4
# IMAGES: NONE
#
# ################################
#
# Have a look at the list of accepted papers in ACM Multimedia 2018 if you are willing to work on some interesting multimedia research problems.
# https://t.co/TEPg200yB6
#
# #MIDAS #ACMMultimedia2018 #ACM #MultimediaResearch #Multimedia #IIITD #NUS #NII
# DATE :  Tue Jul 31 12:11:52 +0000 2018
# FAVORITES:  1
# RETWEET COUNT:  0
# IMAGES: NONE
#
# ################################
#
# RT @goodfellow_ian: https://t.co/hYiWI7ntyk TensorFuzz automates the process of finding inputs that cause some specific testable behavior,…
# DATE :  Tue Jul 31 02:06:26 +0000 2018
# FAVORITES:  0
# RETWEET COUNT:  264
# IMAGES: NONE
#
# ################################
#
# RT @IIITDelhi: Congratulations Dr. @RatnRajiv and team @midasIIITD for getting their paper titled,"Learning and Fusing Multimodal Deep Feat…
# DATE :  Mon Jul 30 07:30:51 +0000 2018
# FAVORITES:  0
# RETWEET COUNT:  2
# IMAGES: NONE
#
# ################################
#
# RT @ylecun: Jitendra Malik, who directs FAIR-Menlo Park, talks about the future of computer vision in his acceptance talk after receiving t…
# DATE :  Sat Jul 28 11:07:11 +0000 2018
# FAVORITES:  0
# RETWEET COUNT:  57
# IMAGES: NONE
#
# ################################
#
# RT @kdnuggets: .@Bloomberg launches free course  "Foundations of #MachineLearning" for those with Strong #Math Backgrounds  https://t.co/9R…
# DATE :  Sat Jul 28 06:14:09 +0000 2018
# FAVORITES:  0
# RETWEET COUNT:  105
# IMAGES: NONE
#
# ################################
#
# RT @TechAtBloomberg: Missed #PyLondinium18? Watch the videos of the keynotes and other speakers now: https://t.co/ZdsCV6csy7
# DATE :  Sat Jul 28 06:13:48 +0000 2018
# FAVORITES:  0
# RETWEET COUNT:  7
# IMAGES: NONE
#
# ################################
#
# RT @IIITDelhi: We are delighted to announce that @IIITDelhi has joined hands with University at Buffalo, the State University of New York f…
# DATE :  Sat Jul 28 04:08:21 +0000 2018
# FAVORITES:  0
# RETWEET COUNT:  6
# IMAGES: NONE
#
# ################################
#
# Get ready for the annual technical fest of @IIITDelhi, Esya, on 17th and 18th August 2018. The theme for this year's edition is Technology for Social Change and all the events will be incorporated with the same.
# Check more details at https://t.co/kpINK6bfU5 #ESYA #MIDAS #IIITD
# DATE :  Fri Jul 27 06:46:44 +0000 2018
# FAVORITES:  3
# RETWEET COUNT:  2
# IMAGES: NONE
#
# ################################
#
# Congratulations Dr. @RatnRajiv and team @midasIIITD for getting their paper titled,"Learning and Fusing Multimodal Deep Features for Acoustic Scene Categorization" accepted in ACM Multimedia 2018, a top-tier conference for multimedia. Visit https://t.co/pEMPKivWvO to join MIDAS.
# DATE :  Fri Jul 27 04:07:31 +0000 2018
# FAVORITES:  8
# RETWEET COUNT:  2
# IMAGES: NONE
#
# ################################
#
# Congratulations MIDAS @midasIIITD intern Prakhar Srivastava @prakharcode for being selected to give a talk in PyCon Poland @pyconpl and PyCon France @pyconfr. #MIDAS #Congratulations #PyCon #IIITD #Python #NUS #NII @pycon @IIITDelhi  @TechAtBloomberg @debanjanbhucs
# DATE :  Wed Jul 25 05:14:35 +0000 2018
# FAVORITES:  5
# RETWEET COUNT:  1
# IMAGES: NONE
#
# ################################
#
# MIDAS@IIITD foundation. https://t.co/LKuzyBHzjm
# DATE :  Tue Jul 24 10:33:23 +0000 2018
# FAVORITES:  2
# RETWEET COUNT:  1
# IMAGES: NONE
#
# ################################
#
# It feels great to be the part of @IIITDelhi. https://t.co/IRRTtIpC6D
# DATE :  Tue Jul 24 10:12:34 +0000 2018
# FAVORITES:  2
# RETWEET COUNT:  1
# IMAGES: NONE
#
# ################################
#
# Thank you, @toonzratn for designing the logo of MIDAS. https://t.co/yx2u2Vs36Z
# DATE :  Tue Jul 24 09:46:26 +0000 2018
# FAVORITES:  4
# RETWEET COUNT:  1
# IMAGES:  1
#
# ################################
#
# We are on Facebook too. Like our page to get our updates. https://t.co/CRaw6KQPSf
#
# #MIDAS #IIITD #MultimediaResearch #NLP #ImageProcessing #DeepLearning #AI4HealthCare #Lipreading #FakeNewsDetection #CodeSwitchedLanguageProcessing #SocialMediaComputing #AI
# DATE :  Mon Jul 23 16:25:05 +0000 2018
# FAVORITES:  3
# RETWEET COUNT:  1
# IMAGES: NONE
#
# ################################
#
# MIDAS is a group of researchers at IIIT-Delhi who study, analyze, and build different multimedia systems for society leveraging multimodal information. MIDAS stands for Multimodal Digital Media Analysis Lab and it is founded by Dr. Rajiv Ratn Shah.
# URL: https://t.co/sPvbKgXKmg
# DATE :  Mon Jul 23 12:53:15 +0000 2018
# FAVORITES:  7
# RETWEET COUNT:  4
# IMAGES: NONE
#
# ################################
